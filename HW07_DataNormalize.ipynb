# %% [markdown]
# ### **[실습-1] 결측치를 제외하고 통계 구하기**
# #### 1. 'mpg.csv' 파일을 읽어서 데이터 프레임을 구성하시오.
# #### 2. 데이터 프레임의 'cty'열에 대한 boxplot 그래프 그리기
# #### 3. 하한값, 상한값 구하기
# #### 4. 극단치를 결측 처리하기
# ##### > 결측 처리 결과 'cty' 값이 NaN인 행 검색
# #### 5. 'cty'의 결측치 제거하고 분석하기
# ##### > model별 cty 평균 구하기

# %%
#### 1. csv 파일을 읽어서 데이터 프레임 구축


mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
#### 2. 데이터 프레임의 'cty'열에 대한 boxplot 그래프 그리기
# Out:
# <AxesSubplot:ylabel='cty'>

# %%
#### 3. 하한값, 상한값 구하기

# %%
#### 4. 극단치를 결측 처리하기
# 하한 ~ 상한 값을 벗어나면 NaN 부여

# %%
##### > 결측 처리 결과 'cty' 값이 NaN인 행 검색
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         honda       civic    1.6  1999    4  manual(m5)   f  NaN   33  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f  NaN   37  r
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f  NaN   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f  NaN   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f  NaN   41  d
#
#        category
# 99   subcompact
# 196     compact
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
#### 5. 'cty'의 결측치 제거하고 분석하기
##### > model별 cty 평균 구하기
# Out:
#                          mean_cty
# model
# 4runner 4wd             15.166667
# a4                      18.857143
# a4 quattro              17.125000
# a6 quattro              16.000000
# altima                  20.666667
# c1500 suburban 2wd      12.800000
# camry                   19.857143
# camry solara            19.857143
# caravan 2wd             15.818182
# civic                   24.000000
# corolla                 25.000000
# corvette                15.400000
# dakota pickup 4wd       12.777778
# durango 4wd             11.857143
# expedition 2wd          11.333333
# explorer 4wd            13.666667
# f150 pickup 4wd         13.000000
# forester awd            18.833333
# grand cherokee 4wd      13.500000
# grand prix              17.000000
# gti                     20.000000
# impreza awd             19.625000
# jetta                   19.750000
# k1500 tahoe 4wd         12.500000
# land cruiser wagon 4wd  12.000000
# malibu                  18.800000
# maxima                  18.666667
# mountaineer 4wd         13.250000
# mustang                 15.888889
# navigator 2wd           11.333333
# new beetle              20.000000
# passat                  18.571429
# pathfinder 4wd          13.750000
# ram 1500 pickup 4wd     11.400000
# range rover             11.500000
# sonata                  19.000000
# tiburon                 18.285714
# toyota tacoma 4wd       15.571429

# %% [markdown]
# ## **[실습-2] mpg 데이터 가공하기**
# #### 1. csv 파일을 읽어서 데이터 프레임 구축
# #### 2. mpg 데이터 프레임에서 'trans'열의 값 빈도 분포를 확인
# #### 3. 'auto' 파생변수 생성
# #### > 'trans' 열 값에 'auto'가 있으면 1, 'manual'이 있으면 0으로 처리, 그 외는 NaN 처리
# #### 4. 'gear' 파생변수 생성
# #### > 'trans' 열 값의 ')' 앞에 값으로 판단, 숫자가 아니면 NaN 처리
# #### 5. 'auto'와 'gear'열의 결측치(NaN) 확인
# #### > 결측치 빈도 확인
# #### > 결측치 행 확인
# #### 6. 'auto'와 'gear'별 분포 수 데이터 프레임 생성
# #### > 단, 결측치(NaN) 행은 사전에 차단

# %%
#### 1. 'mpg.csv' 파일을 읽어서 데이터 프레임 구축
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
## 2. mpg 데이터 프레임에서 'trans'열의 값 빈도 분포 수를 확인
# Out:
# trans
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: count, dtype: int64

# %%
## 3. 'auto' 파생변수 생성
# > 'trans' 열 값에 'auto'가 있으면 1, 'manual'이 있으면 0으로 처리, 그 외는 NaN 처리
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  auto
# 0    compact   1.0
# 1    compact   0.0
# 2    compact   0.0
# 3    compact   1.0
# 4    compact   1.0
# ..       ...   ...
# 229  midsize   1.0
# 230  midsize   0.0
# 231  midsize   1.0
# 232  midsize   0.0
# 233  midsize   1.0
#
# [234 rows x 12 columns]

# %%
## 4. 'gear' 파생변수 생성
# > 'trans' 열 값의 ')' 앞에 값으로 판단, 숫자가 아니면 NaN 처리
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  auto gear
# 0    compact   1.0    5
# 1    compact   0.0    5
# 2    compact   0.0    6
# 3    compact   1.0  NaN
# 4    compact   1.0    5
# ..       ...   ...  ...
# 229  midsize   1.0    6
# 230  midsize   0.0    6
# 231  midsize   1.0    5
# 232  midsize   0.0    5
# 233  midsize   1.0    6
#
# [234 rows x 13 columns]

# %%
## 5. 'auto'와 'gear'열의 결측치(NaN) 확인 
# > 결측치 빈도 확인
# Out:
# 5

# %%
## 5. 'auto'와 'gear'열의 결측치(NaN) 확인 
# > 결측치 행 확인
# Out:
#     manufacturer   model  displ  year  cyl     trans drv  cty  hwy fl  \
# 3           audi      a4    2.0  2008    4  auto(av)   f   21   30  p
# 6           audi      a4    3.1  2008    6  auto(av)   f   18   27  p
# 143       nissan  altima    2.5  2008    4  auto(av)   f   23   31  r
# 146       nissan  altima    3.5  2008    6  auto(av)   f   19   26  p
# 149       nissan  maxima    3.5  2008    6  auto(av)   f   19   25  p
#
#     category  auto gear
# 3    compact   1.0  NaN
# 6    compact   1.0  NaN
# 143  midsize   1.0  NaN
# 146  midsize   1.0  NaN
# 149  midsize   1.0  NaN

# %%
## 6. 'auto'와 'gear'별 분포 수 데이터 프레임 생성
# > 단, 결측치(NaN) 행은 사전에 차단
# Out:
#            cnt_gear
# auto gear
# 0.0  5           58
#      6           19
# 1.0  3            2
#      4           86
#      5           42
#      6           22
